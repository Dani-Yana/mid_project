# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data1 = pd.read_csv('C:\\Users\\Win10 Pro x64\\Documents\\Data_Weiterbildung\\IronHack\\Week_5\\Mid_bootcamp_project\\data\\clean\\theft_stats_clean.csv', sep=";")

# %%
data2 = pd.read_csv('C:\\Users\\Win10 Pro x64\\Documents\\Data_Weiterbildung\\IronHack\\Week_5\\Mid_bootcamp_project\\data\\clean\\traffic_accidents_stats_clean.csv', sep=";")

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39656 entries, 0 to 39655
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   called_at_date       39656 non-null  object
#  1   start_date_incident  39656 non-null  object
#  2   start_time_crime     39656 non-null  int64
#  3   end_date_incident    39656 non-null  object
#  4   end_time_crime       39656 non-null  int64
#  5   lor                  39656 non-null  int64
#  6   loss_amount          39656 non-null  int64
#  7   attempt              39656 non-null  object
#  8   bicycle_type         39656 non-null  object
#  9   crime_type           39656 non-null  object
#  10  record_type          39656 non-null  object
#  11  district             39656 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.6+ MB

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4251 entries, 0 to 4250
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   object_id                         4251 non-null   int64
#  1   federal_state                     4251 non-null   int64
#  2   district                          4251 non-null   object
#  3   lor_2021                          4251 non-null   float64
#  4   year_accident                     4251 non-null   int64
#  5   month_accident                    4251 non-null   int64
#  6   hour_accident                     4251 non-null   int64
#  7   weekday                           4251 non-null   int64
#  8   accident_category                 4251 non-null   int64
#  9   accident_type                     4251 non-null   int64
#  10  accident_subtype                  4251 non-null   int64
#  11  light_conditions                  4251 non-null   int64
#  12  accident_involving_bicycle        4251 non-null   int64
#  13  accident_involving_passenger_car  4251 non-null   int64
#  14  accident_involving_pedestrian     4251 non-null   int64
#  15  accident_involving_motorcycle     4251 non-null   int64
#  16  accident_involving_truck          4251 non-null   int64
#  17  accident_involving_other          4251 non-null   int64
#  18  road_condition                    4251 non-null   int64
#  19  coordinates_1a                    4251 non-null   object
#  20  coordinates_2a                    4251 non-null   object
#  21  coordinates_1b                    4251 non-null   object
#  22  coordinates_2b                    4251 non-null   object
# dtypes: float64(1), int64(17), object(5)
# memory usage: 764.0+ KB

# %%
theft_per_district=data1.groupby('district').size().sort_values(ascending=False).reset_index(name='theft_count')

# %%
theft_per_district
# Out:
#                       district  theft_count
# 0                        Mitte         6211
# 1     Friedrichshain-Kreuzberg         5794
# 2                       Pankow         5382
# 3   Charlottenburg-Wilmersdorf         3933
# 4        Tempelhof-Schoeneberg         3651
# 5                    Neukoelln         2944
# 6            Treptow-Koepenick         2861
# 7          Steglitz-Zehlendorf         2495
# 8                  Lichtenberg         2341
# 9                Reinickendorf         1600
# 10         Marzahn-Hellersdorf         1268
# 11                     Spandau         1176

# %%
ax = sns.countplot(x="district", data=data1, order = data1['district'].value_counts().index)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Win10 Pro x64\AppData\Local\Temp\ipykernel_13100\3309177097.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
ax = sns.countplot(x="district", data=data2, order = data2['district'].value_counts().index)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
ax.set_xlabel("District")
ax.set_ylabel("Number of traffic accidents")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Win10 Pro x64\AppData\Local\Temp\ipykernel_13100\1347694743.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
ax = sns.countplot(x="bicycle_type", data=data1, order = data1['bicycle_type'].value_counts().index)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
ax.set_xlabel("Bicycle Type")
ax.set_ylabel("Number of thefts")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Win10 Pro x64\AppData\Local\Temp\ipykernel_13100\3159431840.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
data1['loss_amount'] = data1['loss_amount'].div(1000)

# %%
ax = sns.barplot(data1, x="bicycle_type", y= 'loss_amount', estimator="sum", errorbar=None)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
ax.set_xlabel("Bicycle Type")
ax.set_ylabel("Loss Amount in Thousand")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Win10 Pro x64\AppData\Local\Temp\ipykernel_13100\1917012259.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
ax = sns.barplot(data1, x="bicycle_type", y= 'loss_amount', errorbar=None)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
ax.set_xlabel("Bicycle Type")
ax.set_ylabel("Loss Amount in Thousand")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Win10 Pro x64\AppData\Local\Temp\ipykernel_13100\3776906362.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
sns.boxplot(x=data1["loss_amount"])
# Out:
# <Axes: xlabel='loss_amount'>
